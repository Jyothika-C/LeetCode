# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val, self.next = val, next


class Solution:
    def addTwoNumbers(self, l1, l2):
        dummy = cur = ListNode(0)
        carry = 0
        while l1 or l2 or carry:
            s = (l1.val if l1 else 0) + (l2.val if l2 else 0) + carry
            carry, digit = divmod(s, 10)
            cur.next = cur = ListNode(digit)
            l1 = l1.next if l1 else None
            l2 = l2.next if l2 else None
        return dummy.next


# one-line list creator
def make(nums):
    head = cur = ListNode(0)
    for n in nums:
        cur.next = cur = ListNode(n)
    return head.next


# input
l1 = make(list(map(int, input().split())))
l2 = make(list(map(int, input().split())))

# solve & print
res = Solution().addTwoNumbers(l1, l2)
while res:
    print(res.val, end=" ")
    res = res.next
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 28
#      24     return head.next
#      25
#      26
#      27 # input
# ---> 28 l1 = make(list(map(int, input().split())))
#      29 l2 = make(list(map(int, input().split())))
#      30
#      31 # solve & print
#
# ValueError: invalid literal for int() with base 10: '1,2'
